# %% [markdown]
# <a href="https://colab.research.google.com/github/meghapoojary114/aiml/blob/main/aiml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
cars_df=pd.read_csv('/content/Cars93 (8).csv')
print(cars_df)
fig,ax=plt.subplots(2,3)
fig.set_figwidth(10)
fig.set_figheight(7)
fig.suptitle("multiple box plots",fontsize=16)
ax[0][0].boxplot(cars_df["Price"][cars_df["Type"]=="Compact"])
ax[0][0].set_title('Compact')
ax[0][1].boxplot(cars_df["Price"][cars_df["Type"]=="Large"])
ax[0][1].set_title('Large')
ax[0][2].boxplot(cars_df["Price"][cars_df["Type"]=="Midsize"])
ax[0][2].set_title('Midsize')
ax[1][0].boxplot(cars_df["Price"][cars_df["Type"]=="Small"])
ax[1][0].set_title('Small')
ax[1][1].boxplot(cars_df["Price"][cars_df["Type"]=="Sporty"])
ax[1][1].set_title('Sporty')
ax[1][2].boxplot(cars_df["Price"][cars_df["Type"]=="Van"])
ax[1][2].set_title('Van')
plt.tight_layout(rect=[0,0,1,0.96])
plt.show()
min_value=np.min(cars_df['Price'])
q1=np.percentile(cars_df['Price'],25)
median=np.median(cars_df['Price'])
q3=np.percentile(cars_df['Price'],75)
max_value=np.max(cars_df['Price'])
print('minimumvalue:',min_value)
print('q1:',q1)
print('median:',median)
print('q3:',q3)
print('maximumvalue:',max_value)
plt.hist(cars_df['MPG.city'],color='black')
plt.xlabel('MPG.city')
plt.title('frequency distribution of mpg.city')
plt.show()
plt.scatter(cars_df["Weight"],cars_df["MPG.city"])
plt.xlabel(cars_df["Weight"])
plt.ylabel("MPG.city")
plt.title("weight vs MPG.city",fontsize=16)
plt.show()
plt.plot(cars_df["EngineSize"],cars_df["Horsepower"])
plt.xlabel("EngineSize")
plt.ylabel("Horsepower")
plt.title('line chart to observe the variation in "EngineSize" against "Horsepower"')
plt.show()
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
cars_df=pd.read_csv('/content/Cars93 (8).csv')
print(cars_df)
a=plt.scatter(cars_df['MPG.city'],cars_df['Wt'],marker='*')
print(a)
plt.xlabel('MPG.city')
plt.ylabel('Weight')
plt.title('relationship between the wieght  the car and MPG.city')
plt.show()
trans=cars_df['am'].value_counts()
print(trans)
trans.plt.bar()
plt.title('bar plot to check the frequency distribution of transmission type of cars')
plt.show()
cars_df['MPG.city'].plot(kind='box')
plt.xlabel('MPG.city')
plt.title('box and whisker plot of mpg')
plt.show()
min_value=np.min(cars_df['MPG.city'])
q1=np.percentile(cars_df['MPG.city'],25)
median=np.median(cars_df['MPG.city'])
q3=np.percentile(cars_df['MPG.city'],75)
max_value=np.max(cars_df['MPG.city'])
print('minimumvalue:',min_value)
print('q1:',q1)
print('median:',median)
print('q3:',q3)
print('maximumvalue:',max_value)
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
cars_df=pd.read_csv('/content/Cars93 (8).csv')
print(cars_df)
a=plt.scatter(cars_df['MPG.city'],cars_df['Weight'],marker='*')
print(a)
plt.xlabel('MPG.city')
plt.ylabel('Weight')
plt.title('relationship between the weight of the car and MPG.city')
plt.show()
trans=cars_df['Type'].value_counts()
print(trans)
trans.plot(kind='bar')
plt.title('box and whisker plot of mpg')
plt.show()
cars_df['MPG.city'].plot(kind='box')
plt.xlabel('MPG.city')
plt.title('box and whisker plot of MPG.city')
plt.show()
min_value=np.min(cars_df['MPG.city'])
q1=np.percentile(cars_df['MPG.city'],25)
median=np.median(cars_df['MPG.city'],)
q3=np.percentile(cars_df['MPG.city'],75)
max_value=np.max(cars_df['MPG.city'])
print('minimumvalue:',min_value)
print('q1:',q1)
print('median:',median)
print('q3:',q3)
print('maximumvalue:',max_value)
plt.title('bar plot to check the frequency distribution of transmission type of cars')
plt.show()
cars_df['MPG.city'].plot(kind='box')
plt.xlabel('MPG.city')
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
cars_df=pd.read_csv('/content/Cars93 (8).csv')
print(cars_df)
a=plt.scatter(cars_df['MPG.city'],cars_df['Weight'],marker='*')
print(a)
plt.xlabel('MPG.city')
plt.ylabel('Weight')
plt.title('relationship between the weight of the car and MPG.city')
plt.show()
trans=cars_df['Type'].value_counts()
print(trans)
trans.plot.bar()
plt.xlabel('transmission')
plt.title('bar plot to check the frequency distribution of transmission type of cars')
plt.show()
cars_df['MPG.city'].plot(kind='box')
plt.xlabel('MPG.city')
plt.title('box and whisker plot of MPG.city')
plt.show()
min_value=np.min(cars_df['MPG.city'])
q1=np.percentile(cars_df['MPG.city'],25)
median=np.median(cars_df['MPG.city'],)
q3=np.percentile(cars_df['MPG.city'],75)
max_value=np.max(cars_df['MPG.city'])
print('minimumvalue:',min_value)
print('q1:',q1)
print('median:',median)
print('q3:',q3)
print('maximumvalue:',max_value)
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...
